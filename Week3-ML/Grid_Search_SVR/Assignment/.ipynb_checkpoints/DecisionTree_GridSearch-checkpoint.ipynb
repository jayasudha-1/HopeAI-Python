# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset.head(5)
# Out:
#    age     sex     bmi  children smoker      charges
# 0   19  female  27.900         0    yes  16884.92400
# 1   18    male  33.770         1     no   1725.55230
# 2   28    male  33.000         3     no   4449.46200
# 3   33    male  22.705         0     no  21984.47061
# 4   32    male  28.880         0     no   3866.85520

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True) #Removing the first column like dummies

# %%
dataset.head(5)
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes
# 0   19  27.900         0  16884.92400         0           1
# 1   18  33.770         1   1725.55230         1           0
# 2   28  33.000         3   4449.46200         1           0
# 3   33  22.705         0  21984.47061         1           0
# 4   32  28.880         0   3866.85520         1           0

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
#param_grid={'criterion':['squared_error','friedman_mse','absolute_error','poisson'],'splitter':['best','random'],'max_features':['int','float','sqrt','log2']}
param_grid = {
    'criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
    'splitter': ['best', 'random'],
    'max_features': ['sqrt', 'log2']  
}
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
#print best parameter
re=grid.cv_results_
print("R score value for best parameter {}:".format(grid.best_params_))
# Out:
# R score value for best parameter {'criterion': 'absolute_error', 'max_features': 'log2', 'splitter': 'random'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.009505      0.002197         0.004271        0.001109
# 1        0.006763      0.001647         0.004315        0.001568
# 2        0.005785      0.001543         0.004727        0.002687
# 3        0.005019      0.000815         0.003029        0.001210
# 4        0.007664      0.001344         0.003784        0.001286
# 5        0.004791      0.002810         0.003529        0.000876
# 6        0.008728      0.001217         0.004031        0.001475
# 7        0.009202      0.002466         0.004508        0.001205
# 8        0.033703      0.001533         0.004226        0.001275
# 9        0.026132      0.006874         0.002658        0.001087
# 10       0.028710      0.002057         0.003913        0.001375
# 11       0.023454      0.003916         0.003589        0.000453
# 12       0.008490      0.002655         0.003119        0.001266
# 13       0.007118      0.001523         0.003200        0.000763
# 14       0.008730      0.000928         0.003239        0.000912
# 15       0.005262      0.001897         0.002300        0.000791
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.607580
# 1   {'criterion': 'squared_error', 'max_features':...           0.670720
# 2   {'criterion': 'squared_error', 'max_features':...           0.690319
# 3   {'criterion': 'squared_error', 'max_features':...           0.674649
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.745074
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.726004
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.742839
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.674388
# 8   {'criterion': 'absolute_error', 'max_features'...           0.742998
# 9   {'criterion': 'absolute_error', 'max_features'...           0.642699
# 10  {'criterion': 'absolute_error', 'max_features'...           0.679025
# 11  {'criterion': 'absolute_error', 'max_features'...           0.736788
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.702275
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.733309
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.737316
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.683865
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.525631           0.758380           0.730261
# 1            0.554386           0.554114           0.620136
# 2            0.391427           0.704353           0.712221
# 3            0.489249           0.764808           0.649627
# 4            0.513759           0.747426           0.706231
# 5            0.516957           0.658800           0.676917
# 6            0.622883           0.760248           0.695230
# 7            0.566585           0.608959           0.673827
# 8            0.594246           0.650989           0.586566
# 9            0.479758           0.685708           0.732351
# 10           0.620662           0.665273           0.701718
# 11           0.600920           0.741036           0.742153
# 12           0.637958           0.719099           0.685113
# 13           0.495898           0.562979           0.678158
# 14           0.585707           0.762749           0.489923
# 15           0.548654           0.647348           0.521452
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.746549         0.673680        0.091622                6
# 1            0.500366         0.579944        0.059176               16
# 2            0.747639         0.649192        0.130263               11
# 3            0.691883         0.654043        0.090886                9
# 4            0.700612         0.682620        0.086597                5
# 5            0.529797         0.621695        0.083333               13
# 6            0.691798         0.702600        0.047892                2
# 7            0.705495         0.645851        0.050593               12
# 8            0.720011         0.658962        0.063690                8
# 9            0.710407         0.650185        0.090268               10
# 10           0.759406         0.685217        0.045562                3
# 11           0.696998         0.703579        0.053993                1
# 12           0.674657         0.683820        0.027474                4
# 13           0.602159         0.614500        0.083715               14
# 14           0.758603         0.666860        0.109971                7
# 15           0.628743         0.606012        0.061199               15

# %%
age=float(input("Age:"))
bmi=float(input("bmi:"))
children=float(input("children:"))
sex_male=int(input("sex male 0 or 1:"))
smoker_yes=int(input("smoker 0 or 1:"))
# Out:
# Age: 25
# bmi: 26
# children: 2
# sex male 0 or 1: 0
# smoker 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[34033.463]
# C:\Users\Jayasudha Kalamegam\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
