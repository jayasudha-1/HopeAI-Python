# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset.head(5)
# Out:
#    age     sex     bmi  children smoker      charges
# 0   19  female  27.900         0    yes  16884.92400
# 1   18    male  33.770         1     no   1725.55230
# 2   28    male  33.000         3     no   4449.46200
# 3   33    male  22.705         0     no  21984.47061
# 4   32    male  28.880         0     no   3866.85520

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True) #Removing the first column like dummies

# %%
dataset.head(5)
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes
# 0   19  27.900         0  16884.92400         0           1
# 1   18  33.770         1   1725.55230         1           0
# 2   28  33.000         3   4449.46200         1           0
# 3   33  22.705         0  21984.47061         1           0
# 4   32  28.880         0   3866.85520         1           0

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test=train_test_split(independent,dependent,test_size=1/3, random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid={'kernel':['linear','rbf'],'C':[1,10,100],'gamma':['auto','scale']}

grid=GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Users\Jayasudha Kalamegam\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [1, 10, 100], 'gamma': ['auto', 'scale'],
#                          'kernel': ['linear', 'rbf']},
#              verbose=3)

# %%
#print best parameter
re=grid.cv_results_
print("R score value for best parameter {}:".format(grid.best_params_))
# Out:
# R score value for best parameter {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.027669      0.002969         0.006340        0.001057        1
# 1        0.037732      0.003745         0.015583        0.002469        1
# 2        0.024975      0.003983         0.005015        0.001191        1
# 3        0.023226      0.003151         0.014251        0.002338        1
# 4        0.030593      0.002282         0.004649        0.001125       10
# 5        0.033502      0.000875         0.015302        0.001178       10
# 6        0.029432      0.004099         0.004220        0.001166       10
# 7        0.026418      0.004428         0.012596        0.001454       10
# 8        0.062668      0.007457         0.005033        0.001363      100
# 9        0.035797      0.004596         0.012730        0.002164      100
# 10       0.061211      0.002425         0.004019        0.001781      100
# 11       0.020417      0.003697         0.011417        0.003678      100
#
#    param_gamma param_kernel                                            params  \
# 0         auto       linear     {'C': 1, 'gamma': 'auto', 'kernel': 'linear'}
# 1         auto          rbf        {'C': 1, 'gamma': 'auto', 'kernel': 'rbf'}
# 2        scale       linear    {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# 3        scale          rbf       {'C': 1, 'gamma': 'scale', 'kernel': 'rbf'}
# 4         auto       linear    {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}
# 5         auto          rbf       {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# 6        scale       linear   {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
# 7        scale          rbf      {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 8         auto       linear   {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}
# 9         auto          rbf      {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}
# 10       scale       linear  {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}
# 11       scale          rbf     {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0           -0.145481           0.024245          -0.252365
# 1           -0.054251          -0.023642          -0.160120
# 2           -0.145481           0.024245          -0.252365
# 3           -0.053229          -0.021311          -0.161725
# 4           -0.052374           0.104434          -0.156399
# 5           -0.052760          -0.022768          -0.160176
# 6           -0.052374           0.104434          -0.156399
# 7           -0.048970          -0.000543          -0.168834
# 8            0.491287           0.557330           0.432315
# 9           -0.043136          -0.007183          -0.154725
# 10           0.491287           0.557330           0.432315
# 11          -0.120809           0.014684          -0.253535
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0           -0.199368          -0.154983        -0.145590        0.092979
# 1           -0.123048          -0.141169        -0.100446        0.052465
# 2           -0.199368          -0.154983        -0.145590        0.092979
# 3           -0.123169          -0.140469        -0.099981        0.053599
# 4           -0.102809          -0.079150        -0.057260        0.087808
# 5           -0.123452          -0.139782        -0.099788        0.052820
# 6           -0.102809          -0.079150        -0.057260        0.087808
# 7           -0.131191          -0.138045        -0.097516        0.062647
# 8            0.466224           0.426625         0.474756        0.047502
# 9           -0.120873          -0.132057        -0.091595        0.056486
# 10           0.466224           0.426625         0.474756        0.047502
# 11          -0.212486          -0.162749        -0.146979        0.092427
#
#     rank_test_score
# 0                10
# 1                 9
# 2                10
# 3                 8
# 4                 3
# 5                 7
# 6                 3
# 7                 6
# 8                 1
# 9                 5
# 10                1
# 11               12

# %%
age=float(input("Age:"))
bmi=float(input("bmi:"))
children=float(input("children:"))
sex_male=int(input("sex male 0 or 1:"))
smoker_yes=int(input("smoker 0 or 1:"))
# Out:
# Age: 20
# bmi: 28
# children: 1
# sex male 0 or 1: 1
# smoker 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[1937.57098611]
# C:\Users\Jayasudha Kalamegam\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
